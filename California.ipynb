# %% [markdown]
# <a href="https://colab.research.google.com/github/Hareesh292/Data_Science/blob/main/California.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('california_cleaned.csv')
df
# Out:
#      index    ID  Building  Year of sale  Month of sale Type of property  \
# 0        0  1030         1        2005.0           11.0        Apartment
# 1        1  1029         1        2005.0           10.0        Apartment
# 2        2  2002         2        2007.0            7.0        Apartment
# 3        3  2031         2        2007.0           12.0        Apartment
# 4        4  1049         1        2004.0           11.0        Apartment
# ..     ...   ...       ...           ...            ...              ...
# 262    262  5044         5           0.0            0.0        Apartment
# 263    263  5047         5           0.0            0.0        Apartment
# 264    264  5048         5           0.0            0.0        Apartment
# 265    265  5050         5           0.0            0.0        Apartment
# 266    266  5051         5           0.0            0.0        Apartment
#
#      Property #  Area (ft.)          Price  Status      Entity        Name  \
# ...

# %%
df.drop('index',axis=1,inplace=True)
df
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 262  5044         5           0.0            0.0        Apartment          44
# 263  5047         5           0.0            0.0        Apartment          47
# 264  5048         5           0.0            0.0        Apartment          48
# 265  5050         5           0.0            0.0        Apartment          50
# 266  5051         5           0.0            0.0        Apartment          51
#
# ...

# %%
df['Entity'].unique()
# Out:
# array(['Individual', 'No', 'Firm'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       267 non-null    int64
#  1   Building                 267 non-null    int64
#  2   Year of sale             267 non-null    float64
#  3   Month of sale            267 non-null    float64
#  4   Type of property         267 non-null    object
#  5   Property #               267 non-null    int64
#  6   Area (ft.)               267 non-null    float64
#  7   Price                    267 non-null    object
#  8   Status                   267 non-null    object
#  9   Entity                   267 non-null    object
#  10  Name                     267 non-null    object
#  11  Surname                  267 non-null    object
#  12  Age at time of purchase  267 non-null    object
#  13  Interval                 267 non-null    object
# ...

# %%
vals = df['Gender'].value_counts()

# %%
plt.pie(vals,labels=vals.index,autopct='%0.2f%%',pctdistance=0.7)
plt.pie([1],colors='white',radius=0.6)
plt.show()

# %%
df['State'].unique()
# Out:
# array(['California', 'Virginia', 'Arizona', 'Oregon', 'Nevada',
#        'Colorado', 'Utah', 'no', 'Kansas', 'Wyoming'], dtype=object)

# %%
a = sns.countplot(x='State',data=df)
plt.xticks(rotation=90)
for i in a.containers:
  a.bar_label(i)

plt.show()

# %%
vals = df['State'].value_counts()

# %%
plt.pie(vals,labels=vals.index,autopct='%0.0f%%')
plt.show()

# %%
df['Source'].unique()
# Out:
# array(['Website', 'Client', 'Agency', 'no'], dtype=object)

# %%
plt.pie(df['Source'].value_counts(),labels=df['Source'].value_counts().index,autopct='%0.2f%%')
plt.show()

# %%
df['Purpose'].unique()
# Out:
# array(['Home', 'Investment', 'no'], dtype=object)

# %%
plt.pie(df['Purpose'].value_counts(),labels=df['Purpose'].value_counts().index,autopct='%0.2f%%')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=df['Age at time of purchase'])
# Out:
# <Axes: xlabel='Age at time of purchase', ylabel='count'>

# %%
sns.countplot(x=df['Interval'])
# Out:
# <Axes: xlabel='Interval', ylabel='count'>

# %%
df['Age at time of purchase'] = df['Age at time of purchase'].replace('0',None)

# %%
df['Age at time of purchase'] = df['Age at time of purchase'].replace(' ',None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       267 non-null    int64
#  1   Building                 267 non-null    int64
#  2   Year of sale             267 non-null    float64
#  3   Month of sale            267 non-null    float64
#  4   Type of property         267 non-null    object
#  5   Property #               267 non-null    int64
#  6   Area (ft.)               267 non-null    float64
#  7   Price                    267 non-null    object
#  8   Status                   267 non-null    object
#  9   Entity                   267 non-null    object
#  10  Name                     267 non-null    object
#  11  Surname                  267 non-null    object
#  12  Age at time of purchase  178 non-null    object
#  13  Interval                 267 non-null    object
# ...

# %%
df1 = df.dropna()
df1
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 173  3040         3        2007.0            6.0        Apartment          40
# 174  1023         1        2005.0            4.0        Apartment          23
# 175  3009         3        2006.0            5.0        Apartment           9
# 176  3052         3        2006.0            3.0        Apartment          52
# 177  3025         3        2007.0            6.0        Apartment          25
#
# ...

# %%
df1['Age at time of purchase'] = df1['Age at time of purchase'].astype(float)
# Out:
# <ipython-input-22-6d1c16f6ad65>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Age at time of purchase'] = df1['Age at time of purchase'].astype(float)

# %%
st.mean(df1['Age at time of purchase'])
# Out:
# 46.151685393258425

# %%
st.median(df1['Age at time of purchase'])
# Out:
# 45.0

# %%
st.variance(df1['Age at time of purchase'])
# Out:
# 164.90906494001143

# %%
df['Country'].unique()
# Out:
# array(['USA', 'UK', 'USA ', 'Belgium', 'Russia', 'Denmark', 'Germany',
#        'Mexico', 'Canada', 'no'], dtype=object)

# %%
df['Country'] = df['Country'].str.strip()

# %%
sns.countplot(x=df['Country'])
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
vals = df['Country'].value_counts()

# %%
plt.pie(vals,labels=vals.index,autopct='%0.2f%%',radius=2.2)
plt.show()

# %%
#------------------------------------ Conclusions------------------------------------------------------------------
# 1)We expect males to buy more property.
# 2)45% of sales are coming from california and 6% for Nevada 4% from oregon and colorado and arizona
# 3)people will purcahse properties from our firm through website more than cliets and agency
# 4)44% of the people are buying property for house and 29% people are buying as an investment.
# 5)we got mode of 48 and mean as 46.15 and median as 45 which means we dont have much outliers in this dataset.
# 6)we can see the interval gharph as right skewed so we expect younger (adult) people to buy more property.
# 7)We get good (70%) sales from USA and (2%) some from canada.
